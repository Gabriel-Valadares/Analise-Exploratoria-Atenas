# %% [markdown]
# <a href="https://colab.research.google.com/github/Gabriel-Valadares/Analise-Exploratoria-Atenas/blob/master/Analisando_os_Dados_do_Airbnb_Atenas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
# *by Gabriel Valadares de Oliveira*
#
# ---
#
# # Análise dos Dados do Airbnb - *Atenas (Grécia)*
#
# O [Airbnb](https://www.airbnb.com.br/) já é considerado como sendo a **maior empresa hoteleira da atualidade**, e isso **sem possuir nenhum hotel**!
#
# Conectando pessoas que querem viajar (e se hospedar) com anfitriões que querem alugar seus imóveis de maneira prática, o Airbnb fornece uma plataforma inovadora para tornar essa hospedagem alternativa.
#
# No final de 2018, a Startup fundada 10 anos atrás, já havia **hospedado mais de 300 milhões** de pessoas ao redor de todo o mundo, desafiando as redes hoteleiras tradicionais.
#
# Uma das iniciativas do Airbnb é disponibilizar dados do site, para algumas das principais cidades do mundo. Por meio do portal [Inside Airbnb](http://insideairbnb.com/get-the-data.html), é possível baixar uma grande quantidade de dados para desenvolver projetos e soluções de *Data Science*.
#
# <center><img alt="Analisando Airbnb" width="20%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>
#
# **Neste *notebook*, iremos analisar os dados referentes à cidade de Atenas (Grécia) e ver quais insights podem ser extraídos a partir de dados brutos.**

# %% [markdown]
# # Sobre Atenas
#
# <center><img alt="Analisando Airbnb" width="60%" src="https://images.memphistours.com/large/405948760_Athens,%20Greece%20-%20Night%20image%20with%20Athens%20from%20above,%20Monastiraki%20Square%20and%20ancient%20Acropolis.jpg"></center>
#
# Foi a principal cidade-estado da Grécia Antiga e, em conjunto com Esparta, é um dos modelos utilizados para entender a organização política dos gregos. Foi um grande centro cultural, influenciado principalmente pelo intenso comércio com as regiões vizinhas. É considerada o berço da democracia, bem como a cidade em que floresceram a filosofia, o teatro, a arte e a vida urbana na Grécia.
#
# A pólis (ou cidade-estado) de Atenas estava localizada na península Ática, uma região do litoral grego muito acidentada e com poucas terras férteis. Apesar disso, a produção agrícola ajudou a impulsionar a economia ateniense, em especial pela produção de azeite, uva e cereais.
#
# Entretanto, foi o desenvolvimento da atividade comercial que impulsionou o crescimento de Atenas e lhe conferiu algumas de suas características mais importantes, como o intenso intercâmbio cultural, além de influenciar na própria estrutura da sociedade ateniense.
#
# Atualmente, a cidade de Atenas é o centro político, econômico e cultural da Grécia, e um destino turístico de grande importância internacional.

# %% [markdown]
# ## Obtenção dos Dados

# %%
# Importando os pacotes necessarios
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
# Importando o arquivo listings.csv para um DataFrame
df = pd.read_csv("http://data.insideairbnb.com/greece/attica/athens/2022-09-20/visualisations/listings.csv")

# %% [markdown]
# ## Análise dos Dados

# %% [markdown]
# **Dicionário das variáveis**
#
# * `id` - Chave que distigue cada linha de registro na tabela. Serve para identificar o imóvel
# * `Name` - Nome do imóvel registrado.
# * `host_id` - O código de identificação do anfitrião.
# * `host_name` - Nome do anfitrião.
# * `neighbourhood_group` - Coluna sem valor válido.
# * `neighbourhood` - Nome do bairro
# * `latitude` - Coordenada de latitude do imóvel.
# * `longitude` - Coordenada de longitude do imóvel.
# * `room_type` - Tipo de quarto oferecido no anúncio do imóvel.
# * `price` - Preço da hospedagem
# * `minimum_nights` - Quantidade mínima de noites requisitadas para a locação.
# * `number_of_reviews` - Quantidade de avaliações deixadas para aquela oferta de locação.
# * `last_review` - Data da última avaliação.
# * `reviews_per_month` - Média de avaliações feitas por mês.
# * `calculated_host_listings_count` - Quantidade de imóveis do anfitrião.
# * `availability_365` - Dias disponíveis dentro de 365 dias.
# * `number_of_reviews_ltm` - Total de avaliações dentro dos últimos 12 meses.
# * `license` - Código da reserva de locação.
#
#
#
# ---
#
#
# Antes de iniciar qualquer análise, vamos verificar a aparência do nosso *dataset*, analisando as 5 primeiras entradas.

# %%
# Mostrando as 5 primeiras entradas
df.head(5)
# Out:
#                    id                                               name  \
# 0            25678448    sweet home in Athens 15 min from center and sea
# 1            36175508   📍Rooftop Studio near Metro Holargos - 5 Min Walk
# 2            14801587  The top rated (99.8% 5-star) stay in whole Ath...
# 3            42384166                                Practical Apartment
# 4  664108377231910173          LOVELY  1-BEDROOM RENTAL UNIT IN HALANDRI
#
#      host_id            host_name  neighbourhood_group neighbourhood  \
# 0  186614918                Vasia                  NaN   ΝΕΟΣ ΚΟΣΜΟΣ
# 1   62879164              Barbara                  NaN     ΠΕΝΤΑΓΩΝΟ
# 2   92466538  Pantelis & Grigoria                  NaN     ΠΕΤΡΑΛΩΝΑ
# 3  337177735                  Dna                  NaN   ΝΕΟΣ ΚΟΣΜΟΣ
# 4  312554982                 Tony                  NaN     ΠΕΝΤΑΓΩΝΟ
#
#     latitude  longitude        room_type  price  minimum_nights  \
# ...

# %% [markdown]
# ---
#
#
# Já nessa amostra podemos identificar alguns valores ausentes e uma coluna vazia, a `neighbourhood_group`, já indicada no dicionário.
#
# Isso nos leva às próximas perguntas.

# %% [markdown]
# ### **Q1. Quantos atributos (variáveis) e quantas entradas o nosso conjunto de dados possui? Quais são os tipos das variáveis?**

# %%
# Identificando o volume de dados do DataFrame
print("Entradas: {}".format(df.shape[0]))
print("Variáveis: {} \n".format(df.shape[1]))

# Descrevendo as variáveis do dataset
df.dtypes
# Out:
# Entradas: 12165
# Variáveis: 18
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group               float64
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %% [markdown]
# ### **Q2. Qual é a porcentagem de valores ausentes no *dataset*?**

# %%
from numpy.ma.core import shape
# Ordenando em ordem decrescente as variáveis por seus valores ausentes
(df.isnull().sum() / df.shape[0]).sort_values(ascending=False)
# Out:
# neighbourhood_group               1.000000
# reviews_per_month                 0.162187
# last_review                       0.162187
# license                           0.111878
# name                              0.000247
# host_name                         0.000082
# number_of_reviews                 0.000000
# number_of_reviews_ltm             0.000000
# availability_365                  0.000000
# calculated_host_listings_count    0.000000
# id                                0.000000
# minimum_nights                    0.000000
# room_type                         0.000000
# longitude                         0.000000
# latitude                          0.000000
# neighbourhood                     0.000000
# host_id                           0.000000
# price                             0.000000
# dtype: float64

# %% [markdown]
# ### **Q3. Qual é o tipo de distribuição das variáveis?**

# %%
# Plotando o histograma das variáveis numéricas
df.hist(bins=15, figsize=(15,10));

# %% [markdown]
# Alguns histogramas não fazem sentido, como o de latitude e longitude, mas há dois que nos chamam a atenção: o de `price` e o de `minimum_nights`. Reparemos que não há sinal de distribuição, o que denota a presença de *outliers*.
#
# Então, vamos estudar alguns valores estatísticos por coluna.

# %% [markdown]
# ### **Q4. Qual é a média dos preços de aluguel?**

# %%
# Obtendo a média da coluna `price``
df.price.mean()
# Out:
# 94.75988491574188

# %%
# Resumo estatístico das variáveis numéricas
df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month',
    'calculated_host_listings_count', 'availability_365']].describe()
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  12165.000000    12165.000000       12165.000000       10192.000000
# mean      94.759885        3.532840          44.118208           1.738131
# std      225.255583       21.634505          74.789939           1.757279
# min       10.000000        1.000000           0.000000           0.010000
# 25%       45.000000        1.000000           2.000000           0.440000
# 50%       64.000000        2.000000          13.000000           1.145000
# 75%      100.000000        2.000000          51.000000           2.480000
# max     8000.000000     1000.000000         798.000000          18.860000
#
#        calculated_host_listings_count  availability_365
# count                    12165.000000      12165.000000
# mean                        13.376326        233.584299
# std                         32.280342        124.293804
# min                          1.000000          0.000000
# ...

# %% [markdown]
# ---
#
#
# Verificando a tabela dos resumos estatísticos, suspeita-se da presença de
# outlier nos dados, haja vista os valores máximos para preço e tempo mínimo de estadia serem muito elevados em relação a 75% e 50%. Ou seja:
#
# * A variável `Price` possui 75% de seus valores abaixo de 100, mas seu valor máximo é 8000.
# * A variável `minimum_nights` possui 75% de seus valores abaixo de 2, mas seu valor máximo é 1000, o que é acima de 365 dias no ano.
#
# Os valores que proporei como limite de corte na tabela serão determinados conforme faça sentido com o gráfico de box plot (como a análise está um nível superficial, não será empregado um método científico formal).
#
# * *`price`*: Valores acima de 3 vezes em relação ao valor máximo de 75% das entradas nessa coluna.
# * *`minimum_nights`*: Valores acima de 2 semanas de estadia.

# %%
# minimum_nights
df.minimum_nights.plot(kind='box', vert=False, figsize=(15, 3))
plt.show()

# ver quantidade de valores acima de 15 dias para minimum_nights
print("\nminimum_nights: valores acima de 15:")
print("{} entradas".format(len(df[df.minimum_nights > 15])))
print("{:.4f}%".format((len(df[df.minimum_nights > 15]) / df.shape[0])*100))
# Out:
# minimum_nights: valores acima de 15:
# 244 entradas
# 2.0058%

# %%
# Price
df.price.plot(kind='box', vert=False, figsize=(15, 3),)
plt.show()

# ver quantidade de valores acima de 300 para price
print("\nprice: valores acima de 300")
print("{} entradas".format(len(df[df.price > 300])))
print("{:.4f}%".format((len(df[df.price > 300]) / df.shape[0])*100))

# df.price.plot(kind='box', vert=False, xlim=(0,1300), figsize=(15,3));
# Out:
# price: valores acima de 300
# 311 entradas
# 2.5565%

# %% [markdown]
# ---
#
#
# Vamos eliminar os outliers e a coluna neighbourhood_group, que está vazia.

# %%
# Eiminando outliers em um novo Dataframe
df_clean = df.copy()

# Baseado no Price
df_clean.drop(df_clean[df_clean.price > 300].index, axis=0, inplace=True)
df_clean.drop(df_clean[df_clean.minimum_nights > 15].index, axis=0, inplace=True)

# Eliminando o neighbourhood_group, pois é uma coluna vazia
df_clean.drop('neighbourhood_group', axis=1, inplace=True)

# %%
# Novos histogramas sem os outliers
df_clean.hist(bins=15, figsize=(15,10));

# %% [markdown]
# ---
#
#
# Agora a distribuição das variáveis parece fazer mais sentido. Agora vamos tentar entender se há alguma correlação entre as variáveis

# %% [markdown]
# ### **Q5. Qual é a correlação existente entre as variáveis?**

# %%
# Matriz de correlação
df_corr = df[['price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 'availability_365']].corr()
df_corr
# Out:
#                                    price  minimum_nights  number_of_reviews  \
# price                           1.000000        0.038425          -0.037353
# minimum_nights                  0.038425        1.000000          -0.024126
# number_of_reviews              -0.037353       -0.024126           1.000000
# reviews_per_month              -0.033546       -0.051460           0.564380
# calculated_host_listings_count  0.010462       -0.028111          -0.012750
# availability_365                0.046733       -0.013962          -0.018990
#
#                                 reviews_per_month  \
# price                                   -0.033546
# minimum_nights                          -0.051460
# number_of_reviews                        0.564380
# reviews_per_month                        1.000000
# calculated_host_listings_count           0.051174
# availability_365                         0.085820
#
#                                 calculated_host_listings_count  \
# ...

# %%
# Heatmap a partir das correlações
sns.heatmap(df_corr, cmap='RdBu', square=True, linecolor='white', annot=True);

# %% [markdown]
# ---
#
# Não há relação minimamente forte entre as variáveis, a não ser, por óbvio, a da quantidade total de avaliações com a média mensal.

# %% [markdown]
# ### **Q6. Qual é o tipo de imóvel mais alugado no Airbnb?**

# %%
# Quantidade de cada tipo de imóvel disponível
df_room = df_clean.groupby(['room_type'])['room_type'].count().sort_values(ascending=False)
df_room
# Out:
# room_type
# Entire home/apt    10406
# Private room        1022
# Hotel room           123
# Shared room           69
# Name: room_type, dtype: int64

# %%
# Porcentagem de cada tipo de imóvel disponível
df_room / df.shape[0]
# Out:
# room_type
# Entire home/apt    0.890341
# Private room       0.092478
# Hotel room         0.011508
# Shared room        0.005672
# Name: room_type, dtype: float64

# %% [markdown]
# ---
#
# Ou seja, a maioria das locações são feitas pela casa inteira, e não apenas quartos privados ou compartilhados.

# %% [markdown]
# ### **Q7. Qual é a localidade mais cara do dataset?**

# %%
# Preços por bairros, na média
df_clean.groupby(['neighbourhood'])['price'].mean().sort_values(ascending=False)
# Out:
# neighbourhood
# ΖΑΠΠΕΙΟ                             109.908397
# ΚΟΛΩΝΑΚΙ                            108.336310
# ΑΚΡΟΠΟΛΗ                            107.669782
# ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ              105.258285
# 1Ο ΝΕΚΡΟΤΑΦΕΙΟ                       96.850000
# ΘΗΣΕΙΟ                               95.437888
# ΚΕΡΑΜΕΙΚΟΣ                           92.315068
# ΚΟΥΚΑΚΙ-ΜΑΚΡΥΓΙΑΝΝΗ                  92.296216
# ΛΥΚΑΒΗΤΤΟΣ                           85.355556
# ΓΚΑΖΙ                                78.072165
# ΣΤΑΔΙΟ                               76.236842
# ΡΗΓΙΛΛΗΣ                             72.000000
# ΙΛΙΣΙΑ                               71.676000
# ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ             71.217933
# ΠΕΝΤΑΓΩΝΟ                            71.202020
# ΠΟΛΥΓΩΝΟ                             69.285714
# ΝΕΟΣ ΚΟΣΜΟΣ                          68.374449
# ΒΟΤΑΝΙΚΟΣ                            67.876404
# ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ     67.282132
# ΠΑΓΚΡΑΤΙ                             66.694611
# ...

# %%
# Plotando os imóveis pela latitude-longitude
df_clean.plot(kind='scatter', x='longitude', y='latitude', alpha=0.4, c=df_clean['price'], s=8, cmap=plt.get_cmap('jet'), figsize=(12,8));

# %% [markdown]
# ---
#
# Reparemos que o centro está colorido de verde, que representa valores mais altos de locação. As regiões mais periféricas estão mais baratas (pintadas de azul mais escuro).

# %% [markdown]
# ### **Q8. Qual é a média do mínimo de noites para aluguel (minimum_nights)?**

# %%
# Média da coluna `minimum_nights`
df_clean.minimum_nights.mean()
# Out:
# 2.0405335628227195

# %%
df.groupby('neighbourhood').agg({'neighbourhood':'size', 'price':'mean'}).rename(columns={'neighbourhood':'Qtd','price':'Média'}).sort_values(by=['Qtd'], ascending=False)
# Out:
#                                    Qtd       Média
# neighbourhood
# ΕΜΠΟΡΙΚΟ ΤΡΙΓΩΝΟ-ΠΛΑΚΑ            2153  139.564793
# ΝΕΟΣ ΚΟΣΜΟΣ                       1170   84.553846
# ΚΟΥΚΑΚΙ-ΜΑΚΡΥΓΙΑΝΝΗ                968  105.529959
# ΜΟΥΣΕΙΟ-ΕΞΑΡΧΕΙΑ-ΝΕΑΠΟΛΗ           841   73.834721
# ΑΓΙΟΣ ΚΩΝΣΤΑΝΤΙΝΟΣ-ΠΛΑΤΕΙΑ ΒΑΘΗΣ   660   75.583333
# ΠΑΓΚΡΑΤΙ                           517   77.299807
# ΠΛΑΤΕΙΑ ΑΤΤΙΚΗΣ                    467   58.972163
# ΠΕΤΡΑΛΩΝΑ                          450   87.193333
# ΑΜΠΕΛΟΚΗΠΟΙ                        364   63.730769
# ΚΟΛΩΝΑΚΙ                           359  124.974930
# ΑΚΡΟΠΟΛΗ                           344  125.941860
# ΘΗΣΕΙΟ                             334  107.119760
# ΚΕΡΑΜΕΙΚΟΣ                         304  111.250000
# ΓΟΥΔΙ                              290   71.706897
# ΙΛΙΣΙΑ                             264   72.757576
# ΣΤΑΔΙΟ                             234  118.705128
# ΚΥΨΕΛΗ                             229   66.755459
# ...

# %% [markdown]
# ## Conclusões

# %% [markdown]
# Em primeiro lugar, apesar da análise estar ainda em nível superficial, foi possível notar outliers nos dados.
#
# Em segundo lugar, nota-se que mesmo em bairros em que há pouco imóvel para locação, a média de preço pode ser pequena ou grande e isso também ocorre em lugares com muitos imóveis. A relação entre preço e quantidade de imóveis para locação parece não existir em Atenas.
#
# Entretanto, pelo que o último gráfico parece mostrar, o valor de locação tende a ser maior quanto mais próximo do centro de Atenas estiver o bairro.
